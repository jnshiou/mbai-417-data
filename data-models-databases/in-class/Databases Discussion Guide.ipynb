# %% [markdown]
# <a href="https://colab.research.google.com/github/brook-miller/mbai-417-data/blob/main/data-models-databases/in-class/Databases%20Discussion%20Guide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# What are your experiences working with databases?  What type of data?

# %% [markdown]
# * response bullet points

# %% [markdown]
# There are a multitude of database options with many more appearing, what factors do you think are driving the increasing numbers and types?

# %% [markdown]
# * response bullet points
